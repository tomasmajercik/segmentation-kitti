# %% [markdown]
# Mount G-drive to this project

# %%
from google.colab import drive
# drive.mount('/content/drive')
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
project_path = "/content/drive/MyDrive/Colab_notebooks/segmentation"
# %cd "$project_path"
# Out:
# /content/drive/MyDrive/Colab_notebooks/segmentation

# %%
import wandb

wandb.login()
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: xmajercik (xstyrak-fiit-stu) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python train.py
# Out:
# Using device: cuda
# wandb: Currently logged in as: xmajercik (xstyrak-fiit-stu) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.23.0
# wandb: Run data is saved locally in /content/drive/MyDrive/Colab_notebooks/segmentation/wandb/run-20251130_150706-2xx1drbe
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run crimson-night-17
# wandb: ⭐️ View project at https://wandb.ai/xstyrak-fiit-stu/cityscape_unet_training
# wandb: 🚀 View run at https://wandb.ai/xstyrak-fiit-stu/cityscape_unet_training/runs/2xx1drbe
# Data loaded, model ready.
# Batch 10/550, Train Loss: 3.0823, Train mIoU: 0.0388, Train Pixel Acc: 0.3071
# Batch 20/550, Train Loss: 2.8602, Train mIoU: 0.0564, Train Pixel Acc: 0.4143
# Batch 30/550, Train Loss: 2.7566, Train mIoU: 0.0703, Train Pixel Acc: 0.4503
# ...
